# %%
from manim import *
# Out:
# Manim Community v0.12.0

# %%
# %%manim SquareToCircle -qm -v INFO
# class SquareToCircle(Scene):
#     def construct(self):
#         # Creating shapes
#         circle = Circle()
#         square = Square()
#
#         #Showing shapes
#         self.play(Create(square))
#         self.play(Transform(square, circle))
#         self.play(FadeOut(square))
# Out:
# ---------------------------------------------------------------------------
# BadParameter                              Traceback (most recent call last)
# <ipython-input-9-05644e644adb> in <module>
# ----> 1 get_ipython().run_cell_magic('manim', 'SquareToCircle -qm -v INFO', 'class SquareToCircle(Scene):\n    def construct(self):\n        # Creating shapes\n        circle = Circle()\n        square = Square()\n\n        #Showing shapes\n        self.play(Create(square))\n        self.play(Transform(square, circle))\n        self.play(FadeOut(square))\n')
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2380             with self.builtin_trap:
#    2381                 args = (magic_arg_s, cell)
# -> 2382                 result = fn(*args, **kwargs)
#    2383             return result
#    2384
#
# <decorator-gen-895> in manim(self, line, cell, local_ns)
#
# ...

# %%
SquareToCircle()
